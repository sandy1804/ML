# %% [markdown]
# <a href="https://colab.research.google.com/github/sandy1804/ML/blob/main/StudentPerformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv("/content/exams.csv")

# %%
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 144    male        group B             master's degree      standard
# 145  female        group B                 high school  free/reduced
# 146  female        group B            some high school      standard
# 147    male        group E                some college      standard
# 148  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  149.000000     149.000000     149.000000
# mean    64.899329      67.046980      65.906040
# std     15.962687      14.795605      15.386174
# min     23.000000      32.000000      31.000000
# 25%     54.000000      57.000000      56.000000
# 50%     65.000000      68.000000      66.000000
# 75%     77.000000      78.000000      76.000000
# max    100.000000     100.000000     100.000000

# %%
df.shape
# Out:
# (149, 8)

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 144    male        group B             master's degree      standard
# 145  female        group B                 high school  free/reduced
# 146  female        group B            some high school      standard
# 147    male        group E                some college      standard
# 148  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 144               completed          80             71             68
# 145                    none          51             57             57
# 146               completed          63             61             66
# 147                    none          60             55             46
# 148               completed         100            100            100

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
# 5  female        group D                 high school      standard
# 6  female        group A           bachelor's degree      standard
# 7    male        group E                some college      standard
# 8    male        group D                 high school      standard
# 9    male        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       149 non-null    object
#  1   race/ethnicity               149 non-null    object
#  2   parental level of education  149 non-null    object
#  3   lunch                        149 non-null    object
#  4   test preparation course      149 non-null    object
#  5   math score                   149 non-null    int64
#  6   reading score                149 non-null    int64
#  7   writing score                149 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 9.4+ KB

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 144   False           False                        False  False
# 145   False           False                        False  False
# 146   False           False                        False  False
# 147   False           False                        False  False
# 148   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Length: 149, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sp.histplot(x='lunch', data=df)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='Count'>

# %%
sp.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sp.pairplot(df)

# %%
sp.barplot(df['gender'],df['reading score'])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='reading score'>
